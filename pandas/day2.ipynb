# %%
import pandas as pd
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib as plt

# %%
d = np.array([360,350,225,211,210,84,70,69,16,15])
ser = pd.Series(d)
plot_acf(ser)
plt.pyplot.show()

# %%
d = np.array([360,350,225,211,210,84,70,69,16,15])
ser = pd.Series(d)
series = Series([60,43,67,50,56,42,50,65,68,43,65,34,47,34,49,41,13,35,53,56,16,43,69,59,48,59,86,55,68,51,33,49,67,77,81,67,71,81,68,70,77,56])
plot_acf(series)
plt.pyplot.show()

# %%
from pandas import Series
from matplotlib import pyplot
from statsmodels.stats.diagnostic import acorr_ljungbox
series = Series([60,43,67,50,56,42,50,65,68,43,65,34,47,34,49,41,13,35,53,56,16,43,69,59,48,59,86,55,68,51,33,49,67,77,81,67,71,81,68,70,77,56])
a= acorr_ljungbox(series,lags=20)
print(len(series))
# pyplot.show()
a[1]
# Out:
# 42
# array([0.0071584 , 0.00725718, 0.0045433 , 0.00081283, 0.00113678,
#        0.00247992, 0.00381133, 0.00637682, 0.01106691, 0.01859529,
#        0.02353087, 0.03623085, 0.04186035, 0.05923107, 0.08188724,
#        0.0868387 , 0.04076219, 0.03893377, 0.03801668, 0.01185807])
