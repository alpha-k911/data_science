# %%
import pandas as pd
import matplotlib as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# df = pd.read_csv(,header=None)
df = pd.Series.from_csv('../data/data_set.csv',header=None,index_col=False)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4141: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)
# 0    236
# dtype: object

# %%
df = pd.read_csv('../data/data_set.csv', header=None);
s = df.transpose()[0]
s
# Out:
# 0     236
# 1     320
# 2     272
# 3     233
# 4     237
# 5     313
# 6     261
# 7     227
# 8     250
# 9     314
# 10    286
# 11    227
# 12    260
# 13    311
# 14    295
# 15    233
# 16    257
# 17    339
# 18    279
# 19    250
# 20    270
# 21    346
# 22    294
# 23    255
# 24    278
# 25    363
# 26    313
# 27    273
# 28    300
# 29    370
#      ...
# 34    335
# 35    288
# 36    308
# 37    402
# 38    353
# 39    316
# 40    325
# 41    405
# 42    393
# 43    319
# 44    327
# 45    442
# 46    383
# 47    332
# 48    361
# 49    446
# 50    387
# 51    357
# 52    374
# 53    466
# 54    410
# 55    370
# 56    379
# 57    487
# 58    419
# 59    378
# 60    393
# 61    506
# 62    458
# 63    387
# Name: 0, Length: 64, dtype: int64

# %%
df = pd.read_csv('../data/data_set_mul.csv', header=None);
s = df.transpose()[0]
s
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
# 5      135
# 6      148
# 7      148
# 8      136
# 9      119
# 10     104
# 11     118
# 12     115
# 13     126
# 14     141
# 15     135
# 16     125
# 17     149
# 18     170
# 19     170
# 20     158
# 21     133
# 22     114
# 23     140
# 24     145
# 25     150
# 26     178
# 27     163
# 28     172
# 29     178
#       ...
# 114    491
# 115    505
# 116    404
# 117    359
# 118    310
# 119    337
# 120    360
# 121    342
# 122    406
# 123    396
# 124    420
# 125    472
# 126    548
# 127    559
# 128    463
# 129    407
# 130    362
# 131    405
# 132    417
# 133    391
# 134    419
# 135    461
# 136    472
# 137    535
# 138    622
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: 0, Length: 144, dtype: int64

# %%
r = seasonal_decompose(s,model='multiplicative',freq=12)
r.plot()
# plt.show()

# %%
r = seasonal_decompose(s,model='additive',freq=4)
r.plot()
# plt.show()
